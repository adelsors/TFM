# %%
import pandas as pd
pd.set_option("display.max_colwidth", 80)
pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 6)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.read_csv('/dbfs/titanic/train.csv')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>PC 17599</td>
#       <td>71.2833</td>
#       <td>C85</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>3</td>
#       <td>Heikkinen, Miss. Laina</td>
#       <td>female</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>STON/O2. 3101282</td>
#       <td>7.9250</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>889</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Johnston, Miss. Catherine Helen "Carrie"</td>
#       <td>female</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>2</td>
#       <td>W./C. 6607</td>
#       <td>23.4500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>890</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Behr, Mr. Karl Howell</td>
#       <td>male</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>111369</td>
#       <td>30.0000</td>
#       <td>C148</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>891</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Dooley, Mr. Patrick</td>
#       <td>male</td>
#       <td>32.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>370376</td>
#       <td>7.7500</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#   </tbody>
# </table>
# <p>891 rows × 12 columns</p>
# </div>

# %%
# specify the column type, categorical or numerical, for each column
C = 'Categorical'
N = 'Numerical'
label_name = 'Survived'
feature_dict = {
    'Pclass': C,
    'Sex': C,
    'Age': N,
    'SibSp': C,
    'Parch': C,
    'Ticket': C,
    'Fare': N,
    'Cabin': C,
    'Embarked': C
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from sklearn import preprocessing

def fillna(df):
    na_list = [i for i in feature_dict.keys() if df[i].isnull().values.any()]
    for i in na_list:
        if feature_dict[i] == N:
            df[i] = df[i].fillna(value=df[i].mean())
        else:
            df[i] = df[i].fillna(method='backfill')
            df[i] = df[i].fillna(method='pad')
            # df[i] = df[i].fillna(value=df[i].value_counts().index[0])

categorical_names = list(map(lambda x: x[0], filter(lambda x: x[1] == C, feature_dict.items())))
def categoricalize(df):
    le = preprocessing.LabelEncoder()
    for column in categorical_names:
        # print((column, df[column].shape))
        df[column] = le.fit_transform(df[column])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fillna(df)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>male</td>
#       <td>22.000000</td>
#       <td>1</td>
#       <td>0</td>
#       <td>A/5 21171</td>
#       <td>7.2500</td>
#       <td>C85</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td>female</td>
#       <td>38.000000</td>
#       <td>1</td>
#       <td>0</td>
#       <td>PC 17599</td>
#       <td>71.2833</td>
#       <td>C85</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>3</td>
#       <td>Heikkinen, Miss. Laina</td>
#       <td>female</td>
#       <td>26.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>STON/O2. 3101282</td>
#       <td>7.9250</td>
#       <td>C123</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>889</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Johnston, Miss. Catherine Helen "Carrie"</td>
#       <td>female</td>
#       <td>29.699118</td>
#       <td>1</td>
#       <td>2</td>
#       <td>W./C. 6607</td>
#       <td>23.4500</td>
#       <td>C148</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>890</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Behr, Mr. Karl Howell</td>
#       <td>male</td>
#       <td>26.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>111369</td>
#       <td>30.0000</td>
#       <td>C148</td>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>891</td>
#       <td>0</td>
#       <td>3</td>
#       <td>Dooley, Mr. Patrick</td>
#       <td>male</td>
#       <td>32.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>370376</td>
#       <td>7.7500</td>
#       <td>C148</td>
#       <td>Q</td>
#     </tr>
#   </tbody>
# </table>
# <p>891 rows × 12 columns</p>
# </div>

# %%
categoricalize(df)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>0</td>
#       <td>2</td>
#       <td>Braund, Mr. Owen Harris</td>
#       <td>1</td>
#       <td>22.000000</td>
#       <td>1</td>
#       <td>0</td>
#       <td>523</td>
#       <td>7.2500</td>
#       <td>81</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1</td>
#       <td>0</td>
#       <td>Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#       <td>0</td>
#       <td>38.000000</td>
#       <td>1</td>
#       <td>0</td>
#       <td>596</td>
#       <td>71.2833</td>
#       <td>81</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1</td>
#       <td>2</td>
#       <td>Heikkinen, Miss. Laina</td>
#       <td>0</td>
#       <td>26.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>669</td>
#       <td>7.9250</td>
#       <td>55</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>889</td>
#       <td>0</td>
#       <td>2</td>
#       <td>Johnston, Miss. Catherine Helen "Carrie"</td>
#       <td>0</td>
#       <td>29.699118</td>
#       <td>1</td>
#       <td>2</td>
#       <td>675</td>
#       <td>23.4500</td>
#       <td>60</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>890</td>
#       <td>1</td>
#       <td>0</td>
#       <td>Behr, Mr. Karl Howell</td>
#       <td>1</td>
#       <td>26.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>8</td>
#       <td>30.0000</td>
#       <td>60</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>891</td>
#       <td>0</td>
#       <td>2</td>
#       <td>Dooley, Mr. Patrick</td>
#       <td>1</td>
#       <td>32.000000</td>
#       <td>0</td>
#       <td>0</td>
#       <td>466</td>
#       <td>7.7500</td>
#       <td>60</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>891 rows × 12 columns</p>
# </div>

# %%
features = df[list(feature_dict.keys())]
feat_type = list(feature_dict.values())
labels = df[label_name]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import autokeras as ak

# It tries 10 different models.
clf = ak.StructuredDataClassifier(max_trials=10)
# Feed the structured data classifier with training data.
clf.fit(features, labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Train for 23 steps, validate for 6 steps
# Epoch 1/1000
# 23/23 [==============================] - 1s 30ms/step - loss: 1.3708 - accuracy: 0.5849 - val_loss: 0.6021 - val_accuracy: 0.7247
# Epoch 2/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8751 - accuracy: 0.6255 - val_loss: 0.5667 - val_accuracy: 0.7022
# Epoch 3/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8194 - accuracy: 0.6129 - val_loss: 0.5999 - val_accuracy: 0.7079
# Epoch 4/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8122 - accuracy: 0.6241 - val_loss: 0.6190 - val_accuracy: 0.6966
# Epoch 5/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8167 - accuracy: 0.6101 - val_loss: 0.6079 - val_accuracy: 0.6910
# Epoch 6/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8096 - accuracy: 0.6171 - val_loss: 0.5900 - val_accuracy: 0.6966
# Epoch 7/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7869 - accuracy: 0.6199 - val_loss: 0.6015 - val_accuracy: 0.6910
# Epoch 8/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7673 - accuracy: 0.6297 - val_loss: 0.5974 - val_accuracy: 0.6685
# Epoch 9/1000
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7431 - accuracy: 0.6339 - val_loss: 0.6230 - val_accuracy: 0.6742
# Epoch 10/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7379 - accuracy: 0.6325 - val_loss: 0.6438 - val_accuracy: 0.6573
# Epoch 11/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7336 - accuracy: 0.6325 - val_loss: 0.6487 - val_accuracy: 0.6517
# Epoch 12/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7290 - accuracy: 0.6283 - val_loss: 0.6545 - val_accuracy: 0.6517
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# Train for 23 steps, validate for 6 steps
# Epoch 1/1000
# 23/23 [==============================] - 1s 28ms/step - loss: 15.5506 - accuracy: 0.4979 - val_loss: 5.3164 - val_accuracy: 0.6742
# Epoch 2/1000
# 23/23 [==============================] - 0s 5ms/step - loss: 8.6161 - accuracy: 0.5638 - val_loss: 0.8519 - val_accuracy: 0.7303
# Epoch 3/1000
# 23/23 [==============================] - 0s 5ms/step - loss: 7.6914 - accuracy: 0.5764 - val_loss: 2.0516 - val_accuracy: 0.7584
# Epoch 4/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 6.2853 - accuracy: 0.5863 - val_loss: 1.4323 - val_accuracy: 0.7472
# Epoch 5/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8817 - accuracy: 0.6129 - val_loss: 1.5461 - val_accuracy: 0.7584
# Epoch 6/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8153 - accuracy: 0.6073 - val_loss: 1.0687 - val_accuracy: 0.7303
# Epoch 7/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0114 - accuracy: 0.5680 - val_loss: 1.3755 - val_accuracy: 0.7303
# Epoch 8/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8734 - accuracy: 0.5680 - val_loss: 1.1183 - val_accuracy: 0.7135
# Epoch 9/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6214 - accuracy: 0.6157 - val_loss: 1.8579 - val_accuracy: 0.7472
# Epoch 10/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5268 - accuracy: 0.5905 - val_loss: 1.0797 - val_accuracy: 0.7079
# Epoch 11/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5002 - accuracy: 0.5975 - val_loss: 1.0304 - val_accuracy: 0.7191
# Epoch 12/1000
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3035 - accuracy: 0.5905 - val_loss: 0.9409 - val_accuracy: 0.7247
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# &lt;IPython.core.display.HTML object&gt;
# Train for 23 steps, validate for 6 steps
# Epoch 1/1000
# 23/23 [==============================] - 1s 51ms/step - loss: 0.7765 - accuracy: 0.6227 - val_loss: 5.9935 - val_accuracy: 0.3652
# Epoch 2/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6879 - accuracy: 0.6297 - val_loss: 4.2983 - val_accuracy: 0.3764
# Epoch 3/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6795 - accuracy: 0.6508 - val_loss: 2.0623 - val_accuracy: 0.4101
# Epoch 4/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.6393 - accuracy: 0.6634 - val_loss: 1.6422 - val_accuracy: 0.4101
# Epoch 5/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6260 - accuracy: 0.6732 - val_loss: 1.3103 - val_accuracy: 0.4326
# Epoch 6/1000
# 23/23 [==============================] - 0s 10ms/step - loss: 0.6420 - accuracy: 0.6564 - val_loss: 0.9625 - val_accuracy: 0.5112
# Epoch 7/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6347 - accuracy: 0.6648 - val_loss: 0.9360 - val_accuracy: 0.5562
# Epoch 8/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6163 - accuracy: 0.6746 - val_loss: 0.8872 - val_accuracy: 0.5618
# Epoch 9/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.6107 - accuracy: 0.6760 - val_loss: 0.7259 - val_accuracy: 0.6067
# Epoch 10/1000
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5780 - accuracy: 0.7055 - val_loss: 0.5550 - val_accuracy: 0.6966
# Epoch 11/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5807 - accuracy: 0.6928 - val_loss: 0.7380 - val_accuracy: 0.6348
# Epoch 12/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5977 - accuracy: 0.6957 - val_loss: 0.6052 - val_accuracy: 0.6629
# Epoch 13/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5738 - accuracy: 0.7055 - val_loss: 0.5523 - val_accuracy: 0.7191
# Epoch 14/1000
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5443 - accuracy: 0.7279 - val_loss: 0.6237 - val_accuracy: 0.6573
# Epoch 15/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5648 - accuracy: 0.7041 - val_loss: 0.5744 - val_accuracy: 0.7022
# Epoch 16/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5469 - accuracy: 0.7209 - val_loss: 0.6127 - val_accuracy: 0.6854
# Epoch 17/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5546 - accuracy: 0.7251 - val_loss: 0.6486 - val_accuracy: 0.6573
# Epoch 18/1000
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5292 - accuracy: 0.7433 - val_loss: 0.5604 - val_accuracy: 0.7247
# Epoch 19/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5324 - accuracy: 0.7391 - val_loss: 0.5509 - val_accuracy: 0.7135
# Epoch 20/1000
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5337 - accuracy: 0.7209 - val_loss: 0.6986 - val_accuracy: 0.6348
# Epoch 21/1000
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5021 - accuracy: 0.7532 - val_loss: 0.6539 - val_accuracy: 0.6629
# Epoch 22/1000
# 23/23 [==============================] - 0s 7ms/step -

# %%
test_df = pd.read_csv('/dbfs/titanic/test.csv')[list(feature_dict.keys())]
test_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pclass</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>male</td>
#       <td>34.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>330911</td>
#       <td>7.8292</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>female</td>
#       <td>47.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>363272</td>
#       <td>7.0000</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>male</td>
#       <td>62.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>240276</td>
#       <td>9.6875</td>
#       <td>NaN</td>
#       <td>Q</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>3</td>
#       <td>male</td>
#       <td>38.5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>SOTON/O.Q. 3101262</td>
#       <td>7.2500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>416</th>
#       <td>3</td>
#       <td>male</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>359309</td>
#       <td>8.0500</td>
#       <td>NaN</td>
#       <td>S</td>
#     </tr>
#     <tr>
#       <th>417</th>
#       <td>3</td>
#       <td>male</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2668</td>
#       <td>22.3583</td>
#       <td>NaN</td>
#       <td>C</td>
#     </tr>
#   </tbody>
# </table>
# <p>418 rows × 9 columns</p>
# </div>

# %%
fillna(test_df)
categoricalize(test_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = clf.predict(test_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import numpy as np

preds = pd.DataFrame({'PassengerId' : range(892,1310), 'Survived' : np.reshape(predictions, (1310-892))})
preds.to_csv('/dbfs/titanic/results-autokeras.csv', index=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
preds
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PassengerId</th>
#       <th>Survived</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>892</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>893</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>894</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>1307</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>416</th>
#       <td>1308</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>417</th>
#       <td>1309</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>418 rows × 2 columns</p>
# </div>
